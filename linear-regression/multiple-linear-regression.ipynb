# %%
# %matplotlib notebook
from sklearn.datasets import make_regression
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
X, y = make_regression(n_samples=100, n_features=2, n_informative=2, n_targets=1, noise=50)

# %%
df = pd.DataFrame({'input1':X[:,0], 'input2':X[:,1], 'output':y})

# %%
df.head()
# Out:
#      input1    input2      output
# 0 -0.565563  1.767825   24.119290
# 1 -1.606347  1.335306  -51.996236
# 2 -1.184058 -0.534630   -9.349131
# 3  0.138116 -0.760984 -116.473405
# 4 -0.599549  1.676780   16.820219

# %%
df.shape
# Out:
# (100, 3)

# %%
fig = plt.figure(figsize = (7, 7))
ax = plt.axes(projection ="3d")
ax.scatter3D(X[:,0], X[:,1], y, color = "green")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X_train,X_test, y_train, y_test = train_test_split(X, y, train_size=0.2, random_state=3)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
print("MAE", mean_absolute_error(y_test, y_pred))
print("MSE", mean_squared_error(y_test, y_pred))
print("R2", r2_score(y_test, y_pred))
# Out:
# MAE 37.37413203712648
# MSE 2122.872175594231
# R2 0.5997948099390412
